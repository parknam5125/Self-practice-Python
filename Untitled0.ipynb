# %% [markdown]
# <a href="https://colab.research.google.com/github/parknam5125/Self-practice-Python/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 16359039717968213470
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 14619377664
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 8340305369330599039
#  physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
#  xla_global_id: 416903419]

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13289416 kB
# MemFree:         8617892 kB
# MemAvailable:   11651640 kB
# Buffers:          114508 kB
# Cached:          3125748 kB
# SwapCached:            0 kB
# Active:           486540 kB
# Inactive:        3748988 kB
# Active(anon):       1612 kB
# Inactive(anon):  1006236 kB
# Active(file):     484928 kB
# Inactive(file):  2742752 kB
# Unevictable:           8 kB
# Mlocked:               8 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:              3476 kB
# Writeback:             0 kB
# AnonPages:        995316 kB
# Mapped:           944408 kB
# Shmem:             12568 kB
# KReclaimable:      94332 kB
# Slab:             141104 kB
# SReclaimable:      94332 kB
# SUnreclaim:        46772 kB
# KernelStack:        5872 kB
# PageTables:        13308 kB
# SecPageTables:         0 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6644708 kB
# Committed_AS:    3638860 kB
# ...

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0xffffffff
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa mmio_stale_data retbleed bhi
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
with open('/content/gdrive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat '/gdrive/My Drive/foo.txt'
# Out:
# cat: '/gdrive/My Drive/foo.txt': Transport endpoint is not connected

# %%
import torch
import torch.nn as nn
import torchvision.datasets as dsets

# %%
import numpy as np
t = np.array([0., 1., 2., 3., 4., 5., 6.])
print(t)
# Out:
# [0. 1. 2. 3. 4. 5. 6.]

# %%
print('Rank of t: ', t.ndim)
print('Shape of t: ', t.shape)
# Out:
# Rank of t:  1
# Shape of t:  (7,)

# %%
print('t[0] t[1] t[-1] = ',t[0], t[1], t[-1])
print('t[2:5] t[4:-1] = ', t[2:5], t[4:-1])
print('t[:2] t[3:] = ', t[:2], t[3:])
# Out:
# t[0] t[1] t[-1] =  0.0 1.0 6.0
# t[2:5] t[4:-1] =  [2. 3. 4.] [4. 5.]
# t[:2] t[3:] =  [0. 1.] [3. 4. 5. 6.]
